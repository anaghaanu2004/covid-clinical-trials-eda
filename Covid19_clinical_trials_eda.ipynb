# %% [markdown]
# # COVID-19 Clinical Trials – Exploratory Data Analysis (EDA)
#
# ## Objective
# To analyze COVID-19 clinical trial data and extract meaningful insights using
# Python and Pandas through Exploratory Data Analysis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv("covid_clinical_trials.csv")
df.head()
# Out:
#    Rank   NCT Number                                              Title  \
# 0     1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1     2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2     3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3     4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4     5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
#
#         Acronym                  Status         Study Results  \
# 0   COVID-IDNow  Active, not recruiting  No Results Available
# 1      COVID-19      Not yet recruiting  No Results Available
# 2   TAC-COVID19              Recruiting  No Results Available
# 3      COVID-19  Active, not recruiting  No Results Available
# 4  TMF-COVID-19              Recruiting  No Results Available
#
#                                           Conditions  \
# 0                                            Covid19
# ...

# %%
df.shape
df.columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5783 entries, 0 to 5782
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Rank                     5783 non-null   int64
#  1   NCT Number               5783 non-null   object
#  2   Title                    5783 non-null   object
#  3   Acronym                  2480 non-null   object
#  4   Status                   5783 non-null   object
#  5   Study Results            5783 non-null   object
#  6   Conditions               5783 non-null   object
#  7   Interventions            4897 non-null   object
#  8   Outcome Measures         5748 non-null   object
#  9   Sponsor/Collaborators    5783 non-null   object
#  10  Gender                   5773 non-null   object
#  11  Age                      5783 non-null   object
#  12  Phases                   3322 non-null   object
#  13  Enrollment               5749 non-null   float64
# ...

# %%
df.isnull().sum()
df.isnull().mean() * 100
# Out:
# Rank                        0.000000
# NCT Number                  0.000000
# Title                       0.000000
# Acronym                    57.115684
# Status                      0.000000
# Study Results               0.000000
# Conditions                  0.000000
# Interventions              15.320768
# Outcome Measures            0.605222
# Sponsor/Collaborators       0.000000
# Gender                      0.172921
# Age                         0.000000
# Phases                     42.555767
# Enrollment                  0.587930
# Funded Bys                  0.000000
# Study Type                  0.000000
# Study Designs               0.605222
# Other IDs                   0.017292
# Start Date                  0.587930
# Primary Completion Date     0.622514
# Completion Date             0.622514
# First Posted                0.000000
# Results First Posted       99.377486
# Last Update Posted          0.000000
# Locations                  10.115857
# ...

# %%
df.drop(['Study Documents', 'Results First Posted'], axis=1, inplace=True)

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['NCT Number', 'Title', 'Acronym', 'Status', 'Study Results',
#        'Conditions', 'Interventions', 'Outcome Measures',
#        'Sponsor/Collaborators', 'Gender', 'Age', 'Phases', 'Funded Bys',
#        'Study Type', 'Study Designs', 'Other IDs', 'Start Date',
#        'Primary Completion Date', 'Completion Date', 'First Posted',
#        'Last Update Posted', 'Locations', 'URL'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Rank                          0
# NCT Number                    0
# Title                         0
# Acronym                    3303
# Status                        0
# Study Results                 0
# Conditions                    0
# Interventions               886
# Outcome Measures             35
# Sponsor/Collaborators         0
# Gender                       10
# Age                           0
# Phases                     2461
# Enrollment                   34
# Funded Bys                    0
# Study Type                    0
# Study Designs                35
# Other IDs                     1
# Start Date                   34
# Primary Completion Date      36
# Completion Date              36
# First Posted                  0
# Last Update Posted            0
# Locations                   585
# URL                           0
# dtype: int64

# %%
df['Status'] = df['Status'].fillna(df['Status'].mode()[0])

# %%
cat_cols = df.select_dtypes(include='object').columns

for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
df.isnull().sum()
# Out:
# Rank                        0
# NCT Number                  0
# Title                       0
# Acronym                     0
# Status                      0
# Study Results               0
# Conditions                  0
# Interventions               0
# Outcome Measures            0
# Sponsor/Collaborators       0
# Gender                      0
# Age                         0
# Phases                      0
# Enrollment                 34
# Funded Bys                  0
# Study Type                  0
# Study Designs               0
# Other IDs                   0
# Start Date                  0
# Primary Completion Date     0
# Completion Date             0
# First Posted                0
# Last Update Posted          0
# Locations                   0
# URL                         0
# dtype: int64

# %%
df['Country'] = df['Locations'].apply(lambda x: str(x).split(',')[-1])

# %%
df['Status'].value_counts().plot(kind='bar', title='Clinical Trial Status')
plt.show()

# %%
df['Phases'].value_counts().plot(kind='bar', title='Trial Phases')
plt.show()

# %%
pd.crosstab(df['Status'], df['Phases']).plot(kind='bar', stacked=True)
plt.title("Status vs Phases")
plt.show()

# %%
df['Start Date'] = pd.to_datetime(df['Start Date'], errors='coerce')

df['Start Date'].dt.year.value_counts().sort_index().plot(kind='line')
plt.title("Trials Started Over Years")
plt.show()

# %% [markdown]
# ## Key Insights
# - Majority of trials are Active or Completed
# - Phase 2 and Phase 3 trials are dominant
# - United States has the highest number of trials
# - Clinical trials increased rapidly during 2020–2021

# %%
df.to_csv("cleaned_covid_clinical_trials.csv", index=False)

# %% [markdown]
# ## Conclusion
# This project demonstrates how exploratory data analysis can be used to
# understand healthcare clinical trial data and extract meaningful insights.
